# %% [markdown]
# # String

# %%
print("Welcome to all of you")
# Out:
# Welcome to all of you

# %%
print("My name is ved Prakash")
print("I am a mentor of Python Basic programing")
# Out:
# My name is ved Prakash
# I am a mantor of Python Basic programing

# %%
print("""My name is ved Prakash
I am a mentor of Python Basic programing""")
# Out:
# My name is ved Prakash
# I am a mentor of Python Basic programing

# %%
print("My name is ved Prakash \nI am a mentor of Python Basic programing")
# Out:
# My name is ved Prakash
# I am a mentor of Python Basic programing

# %%
print('CST Club')
print("It's going to rain today")
# Out:
# CST Club
# It's going to rain today

# %%
print(25)
print(2.3)
# Out:
# 25
# 2.3

# %%
print('hello world')
# Out:
# hello world

# %% [markdown]
# # Variable

# %%
name= "Raman Raghav"
age1=20
age2="20"
height=5.8
print(name)
print(age1)
# Out:
# Raman Raghav
# 20

# %%
print(type(name))
print(type(age1))
print(type(age2))
print(type(height))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'float'>

# %% [markdown]
# # User_Input

# %%
name= input("Enter the name:")
age = int(input(" Enter the age: "))
print("Name: ", name)
print(age)
print(type(name))
print(type(age))
# Out:
# Enter the name:raja
#  Enter the age: 20
# Name:  raja
# 20
# <class 'str'>
# <class 'int'>

# %%
name= input("Enter the name: ")
fatherName=input("Enter the father's name: ")
print("name",name)
print(fatherName)
# Out:
# Enter the name: raja
# Enter the father's name: raman
# name raja
# raman

# %%
num1= int(input(" Enter the 1st number: "))
num2= int(input(" Enter the 2nd number: "))
print(num1)
print(num2)
print(num1+num2)
# Out:
#  Enter the 1st number: 20
#  Enter the 2nd number: 30
# 20
# 30
# 50

# %% [markdown]
# # arithematic operator

# %%
print(10-20)
# Out:
# -10

# %%
print(3**3)
print(20**2)
# Out:
# 27
# 400

# %%
print(8/2)
print(11//2)
# Out:
# 4.0
# 5

# %%
print(20%3)
# Out:
# 2

# %% [markdown]
# # comparison operator

# %%
print(8>20)
# Out:
# False

# %%
print(10==12)
print(10!=20)
# Out:
# False
# True

# %%
num1=20
num2=40
print(num1 != num2)
# Out:
# True

# %% [markdown]
# # logical operator

# %%
marks= 80
print(marks >= 80 and marks< 90)
# Out:
# True

# %%
username= 'cstclub'
password= 12345

un= input("Enter the username: ")
ps= int(input("Enter the password: "))

if ps== password and un==username :
    print("Log in successfull")
else:
    print("Wrong Input")
# Out:
# Enter the username: cstclub
# Enter the password: 12345
# Log in successfull

# %%
print(4>5 or 5>3 or 55<10)
# Out:
# True

# %%
print(not(4<5))
# Out:
# False

# %%
print(not(4==4))
# Out:
# False
